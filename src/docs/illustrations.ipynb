# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
plt.xlabel("Power (MW)")
plt.ylabel("Cost ($)")
plt.plot([ 100,  110,  130,  135],
         [1400, 1600, 2200, 2400],
         "ro-");
plt.savefig('images/cost_curve.png', dpi=150)
